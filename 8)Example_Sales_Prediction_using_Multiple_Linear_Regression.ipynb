# %% [markdown]
# <a href="https://colab.research.google.com/github/thallamsaithrishool12-alt/Applicatios_of_Data_Mining/blob/main/8)Example_Sales_Prediction_using_Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data=pd.read_csv('/content/DATASET-SALES.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         20 non-null     int64
#  1   RADIO      20 non-null     int64
#  2   NEWSPAPER  20 non-null     int64
#  3   SALES      20 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 772.0 bytes

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#     TV  RADIO  NEWSPAPER  SALES
# 0  192     13          9  13.12
# 1   67      8         57   9.50
# 2  137      9         32  12.98
# 3  212     20         31  16.08
# 4  271     16         74  19.15

# %%
X=df[['TV','RADIO','NEWSPAPER']]
y=df[['SALES']]

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X)

# %%
print(f"coefficients:{model.coef_}")
print(f"intercept:{model.intercept_}")
# Out:
# coefficients:[[0.04384584 0.19703517 0.02914625]]
# intercept:[2.18763548]

# %%
mse=mean_squared_error(y,y_pred)
r2=r2_score(y,y_pred)

# %%
print(f"mean squared error:{mse}")
print(f"R_squared:{r2}")
# Out:
# mean squared error:0.6591432816496811
# R_squared:0.9693388854333006

# %%
plt.figure(figsize=(6,4))
plt.scatter(y,y_pred)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual Sales vs Predicted Sales')
plt.show()
